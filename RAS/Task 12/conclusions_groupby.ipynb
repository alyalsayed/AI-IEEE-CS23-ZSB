# %% [markdown]
# # Drawing Conclusions Using Groupby

# %%
import pandas as pd 
import numpy as np

# %%
# Load `winequality_edited.csv`
wines = pd.read_csv("winequality_edited.csv")
wines.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# 2      9.8        5   red
# 3      9.8        6   red
# 4      9.4        5   red

# %% [markdown]
# ### Is a certain type of wine associated with higher quality? if so, which type is better in quality ? white wine

# %%
# Find the mean quality of each wine type (red and white) with groupby
wines.groupby('color')['quality'].mean() # white    5.877909  >> answer
# Out:
# color
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %% [markdown]
# ### What level of acidity receives the highest average rating? low ــــــــــــــــــــــــــــــ

# %%
# create a column in the dataframe [acidity_levels] that tells you the levels of the acidity ['high', 'mod_high', 'medium', 'low'] according
# to the level of pH percentiles [min, 25% , 50%, 75%, max] 
# below 25% is high ---  25% to 50% is mod_high [moderately]  --- 50% to 75% medium ---- higher than 75% is low
# There are easier ways to do this than what you think [there is a specific pandas function for this]

wines['acidity_levels'] = pd.qcut(wines['pH'], q=[0, 0.25, 0.5, 0.75, 1], labels=['high', 'mod_high', 'medium', 'low'])
wines.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity_levels
# 0      9.4        5   red            low
# 1      9.8        5   red       mod_high
# 2      9.8        5   red         medium
# 3      9.8        6   red       mod_high
# 4      9.4        5   red            low

# %%
summary_stats=wines['pH'].describe()
summary_stats
# Out:
# count    6497.000000
# mean        3.218501
# std         0.160787
# min         2.720000
# 25%         3.110000
# 50%         3.210000
# 75%         3.320000
# max         4.010000
# Name: pH, dtype: float64

# %%
# Groupby the newely created acidity level column and get the mean of the quality so you can decide which acidity level
# results in the best quality and answer the question
quality_means = wines.groupby('acidity_levels')['quality'].mean()
quality_means
# the higher the mean quality , the lower the acidity_levels  >> low     5.859593
# Out:
# acidity_levels
# high        5.783469
# mod_high    5.784540
# medium      5.850832
# low         5.859593
# Name: quality, dtype: float64

# %%
# Save changes for the next section as "winequality_edited.csv" -- do not make a stupid mistake !
wines.to_csv('winequality_edited.csv', index=False)
